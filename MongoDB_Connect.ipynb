# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb+srv://<username>:<password>@cluster0.aztrv.mongodb.net/Cluster0?retryWrites=true&w=majority')
client
# Out:
# MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True)

# %%
db = client.gettingStarted
db
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'gettingStarted')

# %%
people = db.people
people
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'gettingStarted'), 'people')
