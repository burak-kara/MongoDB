# %%
from pymongo import MongoClient
from pprint import pprint
from bson.json_util import dumps

# %%
client = MongoClient('mongodb+srv://kibitzer:c7mVVOJzgcDRxCC0@cluster0.aztrv.mongodb.net/?retryWrites=true&w=majority')
client

# %%
# import datetime
# personDocument = {
#   "name": { "first": "Alan", "last": "Turing" },
#   "birth": datetime.datetime(1912, 6, 23),
#   "death": datetime.datetime(1954, 6, 7),
#   "contribs": [ "Turing machine", "Turing test", "Turingery" ],
#   "views": 1250000
# }

# people.insert_one(personDocument)

# people.find_one({ "name.last": "Turing" })

# %%
all_db_names = client.list_database_names()[:-2] # last 2 db is admin and local that are not related
all_db_names
# Out:
# ['gettingStarted',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata']

# %%
# key is database name
# value is an array
# 1st element of this array is db object
# 2nd element is dict of collection name and colleciton object
db_dict = dict()

# %%
for db_name in all_db_names:
    db_dict[db_name] = [client[db_name]]

# %%
db_dict
# Out:
# {'gettingStarted': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'gettingStarted')],
#  'sample_airbnb': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_airbnb')],
#  'sample_analytics': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_analytics')],
#  'sample_geospatial': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_geospatial')],
#  'sample_mflix': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_mflix')],
#  'sample_restaurants': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_restaurants')],
#  'sample_supplies': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_supplies')],
#  'sample_training': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_training')],
#  'sample_weatherdata': [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_weatherdata')]}

# %%
for key, value in db_dict.items():
    db_obj = value[0]
    collections_names = db_obj.list_collection_names()
    
    # keep collection name and colleciton obj as key value
    temp_col_dict = dict()
    for col_name in collections_names:
        temp_col_dict[col_name] = db_obj[col_name]
    
    db_dict[key].append(temp_col_dict)

# %%
db_dict['sample_analytics']
# Out:
# [Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_analytics'),
#  {'accounts': Collection(Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_analytics'), 'accounts'),
#   'transactions': Collection(Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_analytics'), 'transactions'),
#   'customers': Collection(Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_analytics'), 'customers')}]

# %%
for db_name, dict_value in db_dict.items():
    db_obj = dict_value[0]
    col_dict = dict_value[1]
    print(db_name, end='\n')
    for col_name, col_value in col_dict.items():
        print(col_name, end='\n')
        cursor = col_value.find({})
        for inventory in cursor:
            pprint(inventory)
        break
    break
# Out:
# gettingStarted
# people
# {'_id': ObjectId('5ff9beccd2863995d2c9aaa1'),
#  'birth': datetime.datetime(1912, 6, 23, 0, 0),
#  'contribs': ['Turing machine', 'Turing test', 'Turingery'],
#  'death': datetime.datetime(1954, 6, 7, 0, 0),
#  'name': {'first': 'Alan', 'last': 'Turing'},
#  'views': 1250000}
# {'_id': ObjectId('5ff9befa61d3de83cd192bce'),
#  'birth': datetime.datetime(1912, 6, 23, 0, 0),
#  'contribs': ['Turing machine', 'Turing test', 'Turingery'],
#  'death': datetime.datetime(1954, 6, 7, 0, 0),
#  'name': {'first': 'Alan', 'last': 'Turing'},
#  'views': 1250000}
# {'_id': ObjectId('5ff9bfa3e94a48e3350daae0'),
#  'birth': datetime.datetime(1912, 6, 23, 0, 0),
#  'contribs': ['Turing machine', 'Turing test', 'Turingery'],
#  'death': datetime.datetime(1954, 6, 7, 0, 0),
#  'name': {'first': 'Alan', 'last': 'Turing'},
#  'views': 1250000}

# %%
listingsAndReviews = client.sample_airbnb.listingsAndReviews
listingsAndReviews
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.aztrv.mongodb.net:27017', 'cluster0-shard-00-00.aztrv.mongodb.net:27017', 'cluster0-shard-00-01.aztrv.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-paxy43-shard-0', ssl=True), 'sample_airbnb'), 'listingsAndReviews')

# %%
data_cursor = listingsAndReviews.find({})

# %%
data = list(data_cursor)

# %%
len(data)
# Out:
# 5555

# %%
# insert data to another db/collection
# result = client.gettingStarted.test_insert.insert_many(data)
# result.inserted_ids

# %%
# # insert data to another db/collection
# result = client.sample_weatherdata.test_insert.insert_many(data)
# # result.inserted_ids
